# %% [markdown]
# **Q1. What is a probability distribution, exactly? If the values are meant to be random, how can you predict them at all?**

# %% [markdown]
# It tells us which values a random variable is most likely to take on and which values are less likely to take on. A probability distribution is a way to describe how a random variable is distributed, and it tells us which values a random variable is most likely to take on. We are able to make a prediction about the outcome using the concept of probabilities according to the timeline of the data and the occurrences of the random event.

# %% [markdown]
# **Q2. Is there a distinction between true random numbers and pseudo-random numbers, if there is one? Why are the latter considered “good enough”?**

# %% [markdown]
# The difference between a true random number and a pseudo-random number is that true random numbers are generated by unpredictable physical values, whereas pseudo-random numbers are generated by mathematical algorithms (and are therefore entirely computer-generated). True random numbers are unpredictable physical values means. The quality of the pseudo-random numbers is satisfactory since they adhere to a uniform distribution, and the seed used in the generation of PRN is unpredictably and anonymously chosen.

# %% [markdown]
# **Q3. What are the two main factors that influence the behaviour of a &quot;normal&quot; probability distribution?**

# %% [markdown]
# Mean and standard deviation are the two parameters that define a normal distribution. The standard normal distribution is a normal distribution with a mean of 0 and a standard deviation of 1.

# %% [markdown]
# **Q4. Provide a real-life example of a normal distribution.**

# %% [markdown]
# Normal distribution can also be seen in the results of a fair coin toss or dice roll.

# %% [markdown]
# **Q5. In the short term, how can you expect a probability distribution to behave? What do you think will happen as the number of trials grows?**

# %% [markdown]
# When there are fewer trials, the variation increases. The variability will decrease as more tests are performed.

# %% [markdown]
# **Q6. What kind of object can be shuffled by using random.shuffle?**

# %% [markdown]
# list object can be shuffled by using random.shuffle

# %% [markdown]
# **Q7. Describe the math package&#39;s general categories of functions.**

# %% [markdown]
# The general categories of math package are
#
#
# 1. Trigonometric functions
# 2. Quadratic functions
# 3. Exponential functions
# 4. Hyperbolic functions
# 5. Periodic functions
# 6. Arithmetic functions
# 7. Logarithimic functions
# 8. Conversions to Integer

# %% [markdown]
# **Q8. What is the relationship between exponentiation and logarithms?**

# %% [markdown]
# The exponential function is given by ƒ(x) = ex, whereas the logarithmic function is given by g(x) = ln x

# %% [markdown]
# **Q9. What are the three logarithmic functions that Python supports?**

# %% [markdown]
# 1. log2(x) - logarithmic value of x to base 2
# 2. log10(x) - logarithmic value of x to base 10
# 3. log(x,base) - logarithmic value of x to base. If only first parameter is given , it computes its value to base e,natural logarithm
