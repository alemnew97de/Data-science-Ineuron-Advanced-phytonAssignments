# %% [markdown]
# **Q1. Can you create a programme or function that employs both positive and negative indexing? Is there any repercussion if you do so?**

# %%
def calculate(string):
  print(string[0:len(string):2])
  print(string[-1])

string = 'INeuron'
calculate(string)
# Out:
# Iern
# n

# %% [markdown]
# **Q2. What is the most effective way of starting with 1,000 elements in a Python list? Assume that all elements should be set to the same value.**

# %%
list1 = [1000 for item in range(1000)]
list1
# Out:
# [1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
# ...

# %% [markdown]
# **Q3. How do you slice a list to get any other part while missing the rest? (For example, suppose you want to make a new list with the elements first, third, fifth, seventh, and so on.)**

# %%
list1=['first', 'third', 'fifth', 'seventh','ninth']

list1[0:5]
# Out:
# ['first', 'third', 'fifth', 'seventh', 'ninth']

# %% [markdown]
# **Q4. Explain the distinctions between indexing and slicing.**

# %% [markdown]
# **Indexing** is way to extract any single element for data structure by giving its corresping index number
#
# **Slicing** is way to extract either single or series of element by giving series of indexes

# %% [markdown]
# **Q5. What happens if one of the slicing expression&#39;s indexes is out of range?**

# %% [markdown]
# It will give blank output because elements are not present at out of range indexes

# %%
list1=['first', 'third', 'fifth', 'seventh','ninth']

list1[0:10]
# Out:
# ['first', 'third', 'fifth', 'seventh', 'ninth']

# %% [markdown]
# **Q6. If you pass a list to a function, and if you want the function to be able to change the values of the list—so that the list is different after the function returns—what action should you avoid?**

# %%
def function(list):
  list[0]= 13
  return list

list1 = [1,2,3,4,5]
print(id(list1))
list2 = function(list1)
print(id(list2))
# Out:
# 139964249787520
# 139964249787520

# %% [markdown]
# In above, both lists are referring to same memory locatio. However elements of both lists got change.

# %% [markdown]
# **Q7. What is the concept of an unbalanced matrix?**

# %% [markdown]
# A matrix is said to be balanced if and only if each of its cells is also balanced, where a cell is said to be balanced if the value written in that cell is strictly higher than the number of cells adjacent to it in the matrix.If a given cell has a top, bottom, left, or right cell, then those cells are considered adjacent.

# %% [markdown]
# **Q8. Why is it necessary to use either list comprehension or a loop to create arbitrarily large matrices?**

# %% [markdown]
# The production of huge matrices is simplified by using list comprehension or a Loop. It's easier to put into action and less likely to have mistakes because of it. As a bonus, it simplifies code readability. Having to feed yourself manually is also greatly sped up.
